# %%
import pandas as pd

df = pd.read_parquet("/Users/fernando/Documents/GitHub/wikipedia-markdown/data/parsed/articles.parquet")

# %%
df[df["title"].str.contains("Python")]
# Out:
#                                      title  \
# 1016                          Monty Python
# 11079      Monty Python and the Holy Grail
# 11497         Monty Python's Life of Brian
# 11903        Python (programming language)
# 11911                               Python
# 110827  Monty Python's The Meaning of Life
# 113006                      Python molurus
# 130054                  Python (mythology)
# 143177                      Python License
# 166149          Python Software Foundation
# 222650                        Saint-Python
#
#                                                      text      id  \
# 1016    = Monty Python =\n\nMonty Python, also known a...    3998
# 11079   = Monty Python and the Holy Grail =\n\n\nMonty...   40902
# 11497   = Monty Python's Life of Brian =\n\n\nMonty Py...   43008
# 11903   = Python (programming language) =\n\n\n\n\nPyt...   44678
# 11911   = Python =\n\n\n\n\n\n\nPython is the name giv...   44716
# 110827  = Monty Python's The Meaning of Life =\n\n\n\n...  502106
# 113006  = Python molurus =\n\n\n\nPython molurus is a ...  514130
# 130054  = Python (mythology) =\n\n\nIn Greek mythology...  623315
# 143177  = Python License =\n\nThe Python License was a...  692457
# 166149  = Python Software Foundation =\n\n\nThe Python...  776044
# 222650  = Saint-Python =\n\n\nSaint-Python is a commun...  990410
#
#                                                       url
# 1016       https://simple.wikipedia.org/wiki/Monty_Python
# 11079   https://simple.wikipedia.org/wiki/Monty_Python...
# 11497   https://simple.wikipedia.org/wiki/Monty_Python...
# 11903   https://simple.wikipedia.org/wiki/Python_(prog...
# 11911            https://simple.wikipedia.org/wiki/Python
# 110827  https://simple.wikipedia.org/wiki/Monty_Python...
# 113006   https://simple.wikipedia.org/wiki/Python_molurus
# 130054  https://simple.wikipedia.org/wiki/Python_(myth...
# 143177   https://simple.wikipedia.org/wiki/Python_License
# 166149  https://simple.wikipedia.org/wiki/Python_Softw...
# 222650     https://simple.wikipedia.org/wiki/Saint-Python
